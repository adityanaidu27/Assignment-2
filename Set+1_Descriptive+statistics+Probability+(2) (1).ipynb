# %%
#Q1)	Look at the data given below. Plot the data, find the outliers and find out  μ,σ,σ^2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
a=pd.DataFrame({'Name':['Allied Signal', 'Bankers Trust', 'General Mills', 'ITT Industries', 'J.P.Morgan& Co.', 'Lehman Brothers', 'Marriott', 'MCI', 'Merrill Lynch', 'Microsoft', 'Morgan Stanley', 'Sun Microsystems', 'Travelers', 'US Airways', 'Warner-Lambert'
],'Measures':[24,25,25,24,29,28,25,24,40,32,91,25,39,26,35]})
a
# Out:
#                 Name  Measures
# 0      Allied Signal        24
# 1      Bankers Trust        25
# 2      General Mills        25
# 3     ITT Industries        24
# 4    J.P.Morgan& Co.        29
# 5    Lehman Brothers        28
# 6           Marriott        25
# 7                MCI        24
# 8      Merrill Lynch        40
# 9          Microsoft        32
# 10    Morgan Stanley        91
# 11  Sun Microsystems        25
# 12         Travelers        39
# 13        US Airways        26
# 14    Warner-Lambert        35

# %%
x=pd.Series([24.23, 25.53, 25.41, 24.14, 29.62, 28.25, 25.81, 24.39, 40.26, 32.95, 91.36, 25.99, 39.42, 26.71, 35.00])
name=['Allied Signal', 'Bankers Trust', 'General Mills', 'ITT Industries', 'J.P.Morgan& Co.', 'Lehman Brothers', 'Marriott', 'MCI', 'Merrill Lynch', 'Microsoft', 'Morgan Stanley', 'Sun Microsystems', 'Travelers', 'US Airways', 'Warner-Lambert']

# %%
# Pie Plot
plt.figure(figsize=(6,8))
plt.pie(x,labels=name,autopct='%1.0f%%')
plt.show()

# %%
sns.boxplot(x)
# Out:
# <AxesSubplot:>

# %%
x.mean()
# Out:
# 33.27133333333333

# %%
x.std()
# Out:
# 16.945400921222028

# %%
x.var()
# Out:
# 287.1466123809524
